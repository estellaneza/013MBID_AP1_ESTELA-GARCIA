# %%
import pandas as pd

df = pd.read_csv("../data/processed/datos_integrados.csv")
df.head(5)
# Out:
#    edad situacion_vivienda  ingresos objetivo_credito  pct_ingreso  \
# 0    22           ALQUILER     59000         PERSONAL         0.59
# 1    21             PROPIA      9600        EDUCACIÓN         0.10
# 2    25           HIPOTECA      9600            SALUD         0.57
# 3    23           ALQUILER     65500            SALUD         0.53
# 4    24           ALQUILER     54400            SALUD         0.55
#
#    tasa_interes  estado_credito falta_pago  antiguedad_cliente estado_civil  \
# 0         16.02               1          Y                36.0       CASADO
# 1         11.14               0          N                39.0       CASADO
# 2         12.87               1          N                44.0      SOLTERO
# 3         15.23               1          N                36.0       CASADO
# 4         14.27               1          Y                54.0       CASADO
#
#    ... genero limite_credito_tc         nivel_educativo nivel_tarjeta  \
# ...

# %%
resumen = df.info()
print(resumen)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10123 entries, 0 to 10122
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   edad                      10123 non-null  int64
#  1   situacion_vivienda        10123 non-null  object
#  2   ingresos                  10123 non-null  int64
#  3   objetivo_credito          10123 non-null  object
#  4   pct_ingreso               10123 non-null  float64
#  5   tasa_interes              10123 non-null  float64
#  6   estado_credito            10123 non-null  int64
#  7   falta_pago                10123 non-null  object
#  8   antiguedad_cliente        10123 non-null  float64
#  9   estado_civil              10123 non-null  object
#  10  estado_cliente            10123 non-null  object
#  11  genero                    10123 non-null  object
#  12  limite_credito_tc         10123 non-null  float64
# ...

# %%
print(df.loc[1])
# Out:
# edad                                         21
# situacion_vivienda                       PROPIA
# ingresos                                   9600
# objetivo_credito                      EDUCACIÓN
# pct_ingreso                                 0.1
# tasa_interes                              11.14
# estado_credito                                0
# falta_pago                                    N
# antiguedad_cliente                         39.0
# estado_civil                             CASADO
# estado_cliente                           ACTIVO
# genero                                        M
# limite_credito_tc                       12691.0
# nivel_educativo             SECUNDARIO_COMPLETO
# nivel_tarjeta                              Blue
# personas_a_cargo                            3.0
# capacidad_pago                         0.104167
# estabilidad_laboral                    0.238095
# operaciones_mensuales                       3.5
# gasto_medio_mensual                   95.333333
# ...
